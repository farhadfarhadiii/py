# %%
10+10
# Out:
# 20

# %%
20-10
# Out:
# 10

# %%
4*2
# Out:
# 8

# %%
4/2
# Out:
# 2.0

# %%
4%2
# Out:
# 0

# %%
20>10
# Out:
# True

# %%
20<10
# Out:
# False

# %%
20>=20
# Out:
# True

# %%
20<=20
# Out:
# True

# %%
20==20
# Out:
# True

# %%
20!=20
# Out:
# False

# %%
51//4
# Out:
# 12

# %%
a=20

# %%
a="omid"

# %%
v="omid"
print(v)
# Out:
# omid
