# %%
a=2
b=9
c=4
d=7
f=8
g=87
r=25
e=45
p=85
m=20

# %%
if(a>5 and b>5):
    print("is big")

# %%
if(a>5 or b>5):
    print("is big")
# Out:
# is big

# %%
print(not a)
# Out:
# False

# %%
if(f<9 and p>9):
    print("is good")
# Out:
# is good

# %%
if(f<9 or g>90):
    print("is good")
# Out:
# is good

# %%
v=0
print(not v)
# Out:
# True

# %%
if(m>18 and r>20):
    print("is good")
# Out:
# is good

# %%
if(e<50 or r<20):
    print("is good")
# Out:
# is good

# %%
vv=1
print(not vv)
# Out:
# False

# %%
if(g>70 and m<50):
    print("is good")
# Out:
# is good

# %%
if(g>70 or m>50):
    print("is good")
# Out:
# is good

# %%
vv=1-1
print(not vv)
# Out:
# True

# %%
if(g>70 and g<100):
    print("is good")
# Out:
# is good

# %%
if(g>70 or g>100):
    print("is good")
# Out:
# is good

# %%
vv=2-1
print(not vv)
# Out:
# False

# %%
if(a<10 and c<10):
    print("is good")
# Out:
# is good

# %%
if(a<10 or b>10):
    print("is good")
# Out:
# is good

# %%
vv=2-2
print(not vv)
# Out:
# True

# %%
if(m>18 and p>30):
    print("is good")
# Out:
# is good

# %%
if(m>18 or p<30):
    print("is good")
# Out:
# is good

# %%
vv=3-2
print(not vv)
# Out:
# False

# %%
if(c<10 and p>50):
    print("is good")
# Out:
# is good

# %%
if(c<10 or p>100):
    print("is good")
# Out:
# is good

# %%
vv=4-3
print(not vv)
# Out:
# False

# %%
if(d<10 and r>20):
    print("is good")
# Out:
# is good

# %%
if(d<10 or g>100):
    print("is good")
# Out:
# is good

# %%
vv=5-5
print(not vv)
# Out:
# True

# %%
if(e<50 and g>50):
    print("is good")
# Out:
# is good

# %%
if(e<50 or g>100):
    print("is good")
# Out:
# is good

# %%
vv=2*5-10
print(not vv)
# Out:
# True

# %%
z="omid"
w="omid"
x="komail"
u="hamrah"
q="horaaa"
i=3.14
s=True
n=False

# %%
type(z)
# Out:
# str

# %%
type(i)
# Out:
# float

# %%
type(q)
# Out:
# str

# %%
type(u)
# Out:
# str

# %%
type(x)
# Out:
# str

# %%
type(a)
# Out:
# int

# %%
type(s)
# Out:
# bool

# %%
type(b)
# Out:
# int

# %%
type(n)
# Out:
# bool

# %%
type(d)
# Out:
# int

# %%
if z is w:
    print("ok")
# Out:
# ok

# %%
if z is x:
    print("ok")
else:
    print("not ok")
# Out:
# not ok

# %%
if z is u:
    print("ok")
else:
    print("not ok")
# Out:
# not ok

# %%
if z is q:
    print("ok")
else:
    print("not ok")
# Out:
# not ok

# %%
if z is a:
    print("ok")
else:
    print("not ok")
# Out:
# not ok

# %%
if z is w:
    print("ok")
else:
    print("not ok")
# Out:
# ok

# %%
if z is b:
    print("ok")
else:
    print("not ok")
# Out:
# not ok

# %%
if z is c:
    print("ok")
else:
    print("not ok")
# Out:
# not ok

# %%
if z is n:
    print("ok")
else:
    print("not ok")
# Out:
# not ok

# %%
if z is m:
    print("ok")
else:
    print("not ok")
# Out:
# not ok
