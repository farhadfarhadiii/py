# %%
a=20
b=30
c=40
d=50
e=80
k=90
l=40
o=75
print(a+b)
print(a+c)
print(a+d)
print(a+e)
print(a+k)
print(a+l)
print(a+o)
print(b+k)
print(b+o)
print(l+l)
# Out:
# 50
# 60
# 70
# 100
# 110
# 60
# 95
# 120
# 105
# 80

# %%
a=25
b=70
c=80
d=90
e=98
k=95
l=53
o=89
print(a*b)
print(a*c)
print(a*k)
print(a*o)
print(a*l)
print(a*e)
print(a*d)
print(a*a)
print(b*k)
print(k*o)
print(e*k)
# Out:
# 1750
# 2000
# 2375
# 2225
# 1325
# 2450
# 2250
# 625
# 6650
# 8455
# 9310

# %%
a=20
b=30
c=40
d=50
e=79
k=100
l=40
o=75
print(b-a)
print(c-a)
print(d-a)
print(e-a)
print(k-a)
print(l-a)
print(o-a)
print(k-b)
print(o-b)
print(l-l)
# Out:
# 10
# 20
# 30
# 59
# 80
# 20
# 55
# 70
# 45
# 0

# %%
a=10
b=2
c=4
d=5
e=7
k=9
l=3
o=17
print(a**b)
print(a**c)
print(a**d)
print(a**e)
print(a**a)
print(a**k)
print(a**l)
print(a**o)
print(b**k)
print(b**o)
# Out:
# 100
# 10000
# 100000
# 10000000
# 10000000000
# 1000000000
# 1000
# 100000000000000000
# 512
# 131072

# %%
a=10
b=2
c=4
d=5
e=7
k=9
l=3
o=17
print(a/b)
print(a/c)
print(a/d)
print(a/k)
print(a//e)
print(a//k)
print(a%o)
print(a%k)
print(a//b)
print(a//e)
# Out:
# 5.0
# 2.5
# 2.0
# 1.1111111111111112
# 1
# 1
# 10
# 1
# 5
# 1

# %%
a=10
b=2
c=4
d=5
e=7
k=9
l=3
o=17
u=15
if(a<=10 and b<=10):
    print("are small")
if(k<=a and b<=a):
    print("a is small")
if(k>l and k>e):
    print("k is big")
if(k==9 and o==17):
    print("are 9,17")
if(d!=10 and l!=10):
    print("are not 10")
if(a>=10 and o>=10):
    print("are big")
if(k<10 and e<10):
    print("saml")
if(o>10 and u>10):
    print("big")
if(c<10 and d<10):
    print("small")
if(b<15 and e<15):
    print("small")
# Out:
# are small
# a is small
# k is big
# are 9,17
# are not 10
# are big
# saml
# big
# small
# small

# %%
a=10
b=2
c=4
d=5
e=7
k=9
l=3
o=17
u=15
if(o>10 or u>20):
    print("big")
if(a==10 or b>20):
    print("big")
if(k<10 or b>20):
    print("good")
if(b==2 or c>10):
    print("good")
if(b!=10 or a!=10):
    print("good")
if(d==5 or a==5):
    print("good")
if(o>=17 or e>=17):
    print("good")
if(e<=10 or o<=10):
    print("good")
if(u>20 or u==30):
    print("good")
if(k<10 or o<10):
    print("good")
# Out:
# big
# big
# good
# good
# good
# good
# good
# good
# good

# %%
a=1
b=0
c=1
d=0
s=1
e=0
l=1
u=0
k=1
r=0
print(not a)
print(not b)
print(not c)
print(not d)
print(not s)
print(not e)
print(not l)
print(not u)
print(not k)
print(not r)
# Out:
# False
# True
# False
# True
# False
# True
# False
# True
# False
# True

# %%
a=10
b=15
c=20
d=30
e=35
k=40
l=45
o=50
u=55
print(a>5)
print(u>e)
print(c<d)
print(k>c)
print(l!=e)
print(o>a)
print(b!=u)
print(a==10)
print(k<u)
print(u>b)
# Out:
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True

# %%
def up(x):
    if(x==10):
        return(10)
    elif(x<10):
        return up(x+1)
    elif(x>10):
        return up(x-1)
up(5)

# %%
def down(x):
    if(x<=0):
        return(0)
    else:
        return down(x-1)
down(10)

# %%
def up2(x):
    if(x==20):
        return(20)
    elif(x>10):
        return up2(x+1)
    elif(x>20):
        return up2(x-1)
up2(30)

# %%
def up3(x):
    if(x==50):
        return(50)
    elif(x>50):
        return up3(x-1)
    elif(x<50):
        return up3(x+1)
up3(30)

# %%
def up4(x):
    if(x==100):
        return(100)
    elif(x>100):
        return up4(x-1)
    elif(x<100):
        return up4(x+1)
up4(50)

# %%
def up5(x):
    if(x==150):
        return(150)
    elif(x>150):
        return up5(x-1)
    elif(x<150):
        return up5(x+1)
up5(200)

# %%
def up7(x):
    if(x==200):
        return(200)
    elif(x>200):
        return up7(x-1)
    elif(x<200):
        return up7(x+1)
up7(150)

# %%
def up8(x):
    if(x==250):
        return(250)
    elif(x>250):
        return up8(x-1)
    elif(x<250):
        return up8(x+1)
up8(200)

# %%
def up9(x):
    if(x==300):
        return(300)
    elif(x>300):
        return up9(x-1)
    elif(x<300):
        return up9(x+1)
up9(250)

# %%
def up10(x):
    if(x==350):
        return(350)
    elif(x>350):
        return up10(x-1)
    elif(x<350):
        return up10(x+1)
up10(250)
