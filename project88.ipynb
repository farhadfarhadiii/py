# %%
def two(x):
    if x==0:
        return 1
    else:
        return 2 * two(x- 1)
two(3)
# Out:
# 8

# %%
def factorial(n):
    if n==0 or n==1:
        return 1
    else:
       return n*factorial(n-1)
factorial(4)
# Out:
# 24
